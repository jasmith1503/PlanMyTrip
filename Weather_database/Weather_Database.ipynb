# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 747

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
# url = # YOUR CODE HERE
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_desc})
        
    # If an error is experienced, skip the city
    except:
        # print("City not found. Skipping...")
        # modified to include the city name that was not found
        print("This city was not located >> " + city + " Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | jamestown
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | norman wells
# Processing Record 4 of Set 1 | nizhneyansk
# This city was not located >> nizhneyansk Skipping...
# Processing Record 5 of Set 1 | atuona
# Processing Record 6 of Set 1 | gizo
# Processing Record 7 of Set 1 | brazzaville
# Processing Record 8 of Set 1 | pemangkat
# Processing Record 9 of Set 1 | belushya guba
# This city was not located >> belushya guba Skipping...
# Processing Record 10 of Set 1 | butaritari
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | illoqqortoormiut
# This city was not located >> illoqqortoormiut Skipping...
# Processing Record 13 of Set 1 | grand gaube
# Processing Record 14 of Set 1 | georgetown
# Processing Record 15 of Set 1 | avarua
# Processing Record 16 of Set 1 | marsa matruh
# Processing Record 17 of Set 1 | victoria
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | ossora
# Processing Record 20 of Set 1 | lamar
# Processing Record 21 of Set 1 | tsihombe
# This city was not located >> tsihombe Skipping...
# Processing Record 22 of Set 1 | tuktoyaktuk
# Processing Record 23 of Set 1 | hermanus
# Processing Record 24 of Set 1 | yellowknife
# Processing Record 25 of Set 1 | qaanaaq
# Processing Record 26 of Set 1 | vaitupu
# This city was not located >> vaitupu Skipping...
# Processing Record 27 of Set 1 | hithadhoo
# Processing Record 28 of Set 1 | new norfolk
# Processing Record 29 of Set 1 | samusu
# This city was not located >> samusu Skipping...
# Processing Record 30 of Set 1 | lafia
# Processing Record 31 of Set 1 | saint-philippe
# Processing Record 32 of Set 1 | griffith
# Processing Record 33 of Set 1 | college
# Processing Record 34 of Set 1 | carnarvon
# Processing Record 35 of Set 1 | kyra
# Processing Record 36 of Set 1 | kruisfontein
# Processing Record 37 of Set 1 | punta alta
# Processing Record 38 of Set 1 | mataura
# Processing Record 39 of Set 1 | richards bay
# Processing Record 40 of Set 1 | santo amaro da imperatriz
# Processing Record 41 of Set 1 | mount gambier
# Processing Record 42 of Set 1 | ushuaia
# Processing Record 43 of Set 1 | sukumo
# Processing Record 44 of Set 1 | camacha
# Processing Record 45 of Set 1 | misratah
# Processing Record 46 of Set 1 | portland
# Processing Record 47 of Set 1 | thompson
# Processing Record 48 of Set 1 | riyadh
# Processing Record 49 of Set 1 | gladstone
# Processing Record 50 of Set 1 | kodiak
# Processing Record 1 of Set 2 | coihaique
# Processing Record 2 of Set 2 | east london
# Processing Record 3 of Set 2 | san andres
# Processing Record 4 of Set 2 | kapaa
# Processing Record 5 of Set 2 | stoyba
# This city was not located >> stoyba Skipping...
# Processing Record 6 of Set 2 | utiroa
# This city was not located >> utiroa Skipping...
# Processing Record 7 of Set 2 | hasaki
# Processing Record 8 of Set 2 | bathsheba
# Processing Record 9 of Set 2 | marawi
# Processing Record 10 of Set 2 | jiuquan
# Processing Record 11 of Set 2 | muros
# Processing Record 12 of Set 2 | mys shmidta
# This city was not located >> mys shmidta Skipping...
# Processing Record 13 of Set 2 | oranjemund
# Processing Record 14 of Set 2 | palabuhanratu
# This city was not located >> palabuhanratu Skipping...
# Processing Record 15 of Set 2 | caucaia
# Processing Record 16 of Set 2 | mareeba
# Processing Record 17 of Set 2 | dikson
# Processing Record 18 of Set 2 | montgomery
# Processing Record 19 of Set 2 | chake chake
# Processing Record 20 of Set 2 | ponta do sol
# Processing Record 21 of Set 2 | arraial do cabo
# Processing Record 22 of Set 2 | poum
# Processing Record 23 of Set 2 | ciras
# This city was not located >> ciras Skipping...
# Processing Record 24 of Set 2 | taolanaro
# This city was not located >> taolanaro Skipping...
# Processing Record 25 of Set 2 | caravelas
# Processing Record 26 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 27 of Set 2 | barrow
# Processing Record 28 of Set 2 | valparaiso
# Processing Record 29 of Set 2 | praia da vitoria
# Processing Record 30 of Set 2 | temaraia
# This city was not located >> temaraia Skipping...
# Processing Record 31 of Set 2 | champerico
# Processing Record 32 of Set 2 | esperance
# Processing Record 33 of Set 2 | port lincoln
# Processing Record 34 of Set 2 | taoudenni
# Processing Record 35 of Set 2 | vila velha
# Processing Record 36 of Set 2 | kaitangata
# Processing Record 37 of Set 2 | gamba
# Processing Record 38 of Set 2 | poyarkovo
# Processing Record 39 of Set 2 | aden
# Processing Record 40 of Set 2 | castro
# Processing Record 41 of Set 2 | guerrero negro
# Processing Record 42 of Set 2 | khatanga
# Processing Record 43 of Set 2 | sassandra
# Processing Record 44 of Set 2 | santa lucia
# Processing Record 45 of Set 2 | nisia floresta
# Processing Record 46 of Set 2 | bambous virieux
# Processing Record 47 of Set 2 | puerto ayora
# Processing Record 48 of Set 2 | sira
# Processing Record 49 of Set 2 | shelburne
# Processing Record 50 of Set 2 | la serena
# Processing Record 1 of Set 3 | oyama
# Processing Record 2 of Set 3 | tirau
# Processing Record 3 of Set 3 | verkhnyaya inta
# Processing Record 4 of Set 3 | narsaq
# Processing Record 5 of Set 3 | asfi
# Processing Record 6 of Set 3 | attawapiskat
# This city was not located >> attawapiskat Skipping...
# Processing Record 7 of Set 3 | kirkwall
# Processing Record 8 of Set 3 | arlit
# Processing Record 9 of Set 3 | sorong
# Processing Record 10 of Set 3 | villa carlos paz
# Processing Record 11 of Set 3 | mahebourg
# Processing Record 12 of Set 3 | upernavik
# Processing Record 13 of Set 3 | kokkola
# Processing Record 14 of Set 3 | pangai
# Processing Record 15 of Set 3 | sorland
# Processing Record 16 of Set 3 | yingzhong
# This city was not located >> yingzhong Skipping...
# Processing Record 17 of Set 3 | lompoc
# Processing Record 18 of Set 3 | presidencia roque saenz pena
# Processing Record 19 of Set 3 | vestmannaeyjar
# Processing Record 20 of Set 3 | atlantic city
# Processing Record 21 of Set 3 | katsuura
# Processing Record 22 of Set 3 | marcona
# This city was not located >> marcona Skipping...
# Processing Record 23 of Set 3 | nikolskoye
# Processing Record 24 of Set 3 | umzimvubu
# This city was not located >> umzimvubu Skipping...
# Processing Record 25 of Set 3 | hobart
# Processing Record 26 of Set 3 | bluff
# Processing Record 27 of Set 3 | bichura
# Processing Record 28 of Set 3 | paamiut
# Processing Record 29 of Set 3 | klaksvik
# Processing Record 30 of Set 3 | canchungo
# Processing Record 31 of Set 3 | sao filipe
# Processing Record 32 of Set 3 | nome
# Processing Record 33 of Set 3 | agar
# Processing Record 34 of Set 3 | molina
# Processing Record 35 of Set 3 | pisco
# Processing Record 36 of Set 3 | kalmunai
# Processing Record 37 of Set 3 | provideniya
# Processing Record 38 of Set 3 | mar del plata
# Processing Record 39 of Set 3 | tasiilaq
# Processing Record 40 of Set 3 | tonj
# Processing Record 41 of Set 3 | faya
# Processing Record 42 of Set 3 | santa cruz
# Processing Record 43 of Set 3 | cape town
# Processing Record 44 of Set 3 | bethel
# Processing Record 45 of Set 3 | egvekinot
# Processing Record 46 of Set 3 | zeya
# Processing Record 47 of Set 3 | te anau
# Processing Record 48 of Set 3 | nueva guinea
# Processing Record 49 of Set 3 | busselton
# Processing Record 50 of Set 3 | clyde river
# Processing Record 1 of Set 4 | geraldton
# Processing Record 2 of Set 4 | bredasdorp
# Processing Record 3 of Set 4 | hervey bay
# Processing Record 4 of Set 4 | cherskiy
# Processing Record 5 of Set 4 | santa maria
# Processing Record 6 of Set 4 | sentyabrskiy
# This city was not located >> sentyabrskiy Skipping...
# Processing Record 7 of Set 4 | mackenzie
# Processing Record 8 of Set 4 | souillac
# Processing Record 9 of Set 4 | qaqortoq
# Processing Record 10 of Set 4 | ouro fino
# Processing Record 11 of Set 4 | viedma
# Processing Record 12 of Set 4 | carberry
# Processing Record 13 of Set 4 | gorontalo
# Processing Record 14 of Set 4 | kijang
# Processing Record 15 of Set 4 | bubaque
# Processing Record 16 of Set 4 | hilo
# Processing Record 17 of Set 4 | bagado
# Processing Record 18 of Set 4 | shingu
# Processing Record 19 of Set 4 | port elizabeth
# Processing Record 20 of Set 4 | nsunga
# Processing Record 21 of Set 4 | mushabani
# Processing Record 22 of Set 4 | veraval
# Processing Record 23 of Set 4 | san quintin
# Processing Record 24 of Set 4 | leme
# Processing Record 25 of Set 4 | sioux lookout
# Processing Record 26 of Set 4 | rundu
# Processing Record 27 of Set 4 | namibe
# Processing Record 28 of Set 4 | hobyo
# Processing Record 29 of Set 4 | kurumkan
# Processing Record 30 of Set 4 | kalemie
# Processing Record 31 of Set 4 | quartz hill
# Processing Record 32 of Set 4 | antofagasta
# Processing Record 33 of Set 4 | ancud
# Processing Record 34 of Set 4 | rocha
# Processing Record 35 of Set 4 | barentsburg
# This city was not located >> barentsburg Skipping...
# Processing Record 36 of Set 4 | carutapera
# Processing Record 37 of Set 4 | lavrentiya
# Processing Record 38 of Set 4 | vanimo
# Processing Record 39 of Set 4 | tual
# Processing Record 40 of Set 4 | vaini
# Processing Record 41 of Set 4 | taltal
# Processing Record 42 of Set 4 | supe
# Processing Record 43 of Set 4 | torbay
# Processing Record 44 of Set 4 | saleaula
# This city was not located >> saleaula Skipping...
# Processing Record 45 of Set 4 | shimoda
# Processing Record 46 of Set 4 | tautira
# Processing Record 47 of Set 4 | luderitz
# Processing Record 48 of Set 4 | alice springs
# Processing Record 49 of Set 4 | jurilovca
# Processing Record 50 of Set 4 | pokrovsk
# Processing Record 1 of Set 5 | svetlogorsk
# Processing Record 2 of Set 5 | fukue
# Processing Record 3 of Set 5 | mpika
# Processing Record 4 of Set 5 | batsfjord
# Processing Record 5 of Set 5 | nicoya
# Processing Record 6 of Set 5 | saint-augustin
# Processing Record 7 of Set 5 | kerema
# Processing Record 8 of Set 5 | coahuayana
# Processing Record 9 of Set 5 | tessalit
# Processing Record 10 of Set 5 | amderma
# This city was not located >> amderma Skipping...
# Processing Record 11 of Set 5 | camocim
# Processing Record 12 of Set 5 | jagatsinghapur
# Processing Record 13 of Set 5 | kamenskoye
# This city was not located >> kamenskoye Skipping...
# Processing Record 14 of Set 5 | leningradskiy
# Processing Record 15 of Set 5 | sambava
# Processing Record 16 of Set 5 | sorvag
# This city was not located >> sorvag Skipping...
# Processing Record 17 of Set 5 | saskylakh
# Processing Record 18 of Set 5 | maxixe
# Processing Record 19 of Set 5 | shishou
# Processing Record 20 of Set 5 | vlasikha
# Processing Record 21 of Set 5 | kiruna
# Processing Record 22 of Set 5 | road town
# Processing Record 23 of Set 5 | jacareacanga
# Processing Record 24 of Set 5 | sao joao da barra
# Processing Record 25 of Set 5 | ocampo
# Processing Record 26 of Set 5 | faanui
# Processing Record 27 of Set 5 | boende
# Processing Record 28 of Set 5 | la ronge
# Processing Record 29 of Set 5 | tura
# Processing Record 30 of Set 5 | saint george
# Processing Record 31 of Set 5 | armacao dos buzios
# This city was not located >> armacao dos buzios Skipping...
# Processing Record 32 of Set 5 | kyshtovka
# Processing Record 33 of Set 5 | uruzgan
# Processing Record 34 of Set 5 | codrington
# Processing Record 35 of Set 5 | hualmay
# Processing Record 36 of Set 5 | dalvik
# Processing Record 37 of Set 5 | kushiro
# Processing Record 38 of Set 5 | isangel
# Processing Record 39 of Set 5 | ngunguru
# Processing Record 40 of Set 5 | mattru
# Processing Record 41 of Set 5 | poros
# Processing Record 42 of Set 5 | yumen
# Processing Record 43 of Set 5 | flinders
# Processing Record 44 of Set 5 | waddan
# Processing Record 45 of Set 5 | kremnica
# Processing Record 46 of Set 5 | saint-pierre
# Processing Record 47 of Set 5 | kristiinankaupunki
# Processing Record 48 of Set 5 | los llanos de aridane
# Processing Record 49 of Set 5 | nizhniy kuranakh
# Processing Record 50 of Set 5 | tabiauea
# This city was not located >> tabiauea Skipping...
# Processing Record 1 of Set 6 | suez
# Processing Record 2 of Set 6 | kavieng
# Processing Record 3 of Set 6 | korla
# Processing Record 4 of Set 6 | terney
# Processing Record 5 of Set 6 | dhidhdhoo
# Processing Record 6 of Set 6 | alappuzha
# Processing Record 7 of Set 6 | linxia
# Processing Record 8 of Set 6 | half moon bay
# Processing Record 9 of Set 6 | dolores
# Processing Record 10 of Set 6 | huilong
# Processing Record 11 of Set 6 | patnanungan
# Processing Record 12 of Set 6 | hannibal
# Processing Record 13 of Set 6 | anaimalai
# Processing Record 14 of Set 6 | abha
# Processing Record 15 of Set 6 | kongolo
# Processing Record 16 of Set 6 | shahr-e kord
# Processing Record 17 of Set 6 | tomohon
# Processing Record 18 of Set 6 | brainerd
# Processing Record 19 of Set 6 | ionia
# Processing Record 20 of Set 6 | noumea
# Processing Record 21 of Set 6 | bila krynytsya
# Processing Record 22 of Set 6 | fairbanks
# Processing Record 23 of Set 6 | bolungarvik
# This city was not located >> bolungarvik Skipping...
# Processing Record 24 of Set 6 | cabo rojo
# Processing Record 25 of Set 6 | malwan
# This city was not located >> malwan Skipping...
# Processing Record 26 of Set 6 | ribeira grande
# Processing Record 27 of Set 6 | port alfred
# Processing Record 28 of Set 6 | tacuarembo
# Processing Record 29 of Set 6 | longyearbyen
# Processing Record 30 of Set 6 | chokurdakh
# Processing Record 31 of Set 6 | esso
# Processing Record 32 of Set 6 | ust-ilimsk
# Processing Record 33 of Set 6 | san vicente
# Processing Record 34 of Set 6 | narang
# Processing Record 35 of Set 6 | betsiamites
# Processing Record 36 of Set 6 | moron
# Processing Record 37 of Set 6 | lebanon
# Processing Record 38 of Set 6 | nanortalik
# Processing Record 39 of Set 6 | bonavista
# Processing Record 40 of Set 6 | ayan
# Processing Record 41 of Set 6 | aknada
# Processing Record 42 of Set 6 | buchanan
# Processing Record 43 of Set 6 | serra talhada
# Processing Record 44 of Set 6 | inyonga
# Processing Record 45 of Set 6 | meadow lake
# Processing Record 46 of Set 6 | adiake
# Processing Record 47 of Set 6 | maraa
# Processing Record 48 of Set 6 | gat
# Processing Record 49 of Set 6 | cabo san lucas
# Processing Record 50 of Set 6 | soe
# Processing Record 1 of Set 7 | dukat
# Processing Record 2 of Set 7 | morgan city
# Processing Record 3 of Set 7 | tabou
# Processing Record 4 of Set 7 | aswan
# Processing Record 5 of Set 7 | rusape
# Processing Record 6 of Set 7 | oistins
# Processing Record 7 of Set 7 | maraba
# Processing Record 8 of Set 7 | itarema
# Processing Record 9 of Set 7 | dingle
# Processing Record 10 of Set 7 | aklavik
# Processing Record 11 of Set 7 | salalah
# Processing Record 12 of Set 7 | natal
# Processing Record 13 of Set 7 | yangjiang
# Processing Record 14 of Set 7 | puerto del rosario
# Processing Record 15 of Set 7 | dunedin
# Processing Record 16 of Set 7 | salta
# Processing Record 17 of Set 7 | linhares
# Processing Record 18 of Set 7 | ventspils
# Processing Record 19 of Set 7 | lagoa
# Processing Record 20 of Set 7 | shepetivka
# Processing Record 21 of Set 7 | siena
# Processing Record 22 of Set 7 | veshenskaya
# Processing Record 23 of Set 7 | coquimbo
# Processing Record 24 of Set 7 | santa rosa
# Processing Record 25 of Set 7 | bahia blanca
# Processing Record 26 of Set 7 | virginia beach
# Processing Record 27 of Set 7 | tiznit
# Processing Record 28 of Set 7 | port moresby
# Processing Record 29 of Set 7 | yulara
# Processing Record 30 of Set 7 | yar-sale
# Processing Record 31 of Set 7 | alugan
# Processing Record 32 of Set 7 | san policarpo
# Processing Record 33 of Set 7 | eyl
# Processing Record 34 of Set 7 | aksarka
# Processing Record 35 of Set 7 | zhangye
# Processing Record 36 of Set 7 | wucheng
# Processing Record 37 of Set 7 | chuy
# Processing Record 38 of Set 7 | halalo
# This city was not located >> halalo Skipping...
# Processing Record 39 of Set 7 | adrar
# Processing Record 40 of Set 7 | moba
# Processing Record 41 of Set 7 | umm lajj
# Processing Record 42 of Set 7 | khorramabad
# Processing Record 43 of Set 7 | tiksi
# Processing Record 44 of Set 7 | tuatapere
# Processing Record 45 of Set 7 | molochnoye
# Processing Record 46 of Set 7 | quballat
# Processing Record 47 of Set 7 | alofi
# Processing Record 48 of Set 7 | sillanwali
# Processing Record 49 of Set 7 | svetlyy
# Processing Record 50 of Set 7 | burnie
# Processing Record 1 of Set 8 | pangnirtung
# Processing Record 2 of Set 8 | zhezkazgan
# Processing Record 3 of Set 8 | uk
# This city was not located >> uk Skipping...
# Processing Record 4 of Set 8 | monteagudo
# Processing Record 5 of Set 8 | dolna banja
# This city was not located >> dolna banja Skipping...
# Processing Record 6 of Set 8 | broome
# Processing Record 7 of Set 8 | san patricio
# Processing Record 8 of Set 8 | plerin
# Processing Record 9 of Set 8 | naze
# Processing Record 10 of Set 8 | kikwit
# Processing Record 11 of Set 8 | ermelo
# Processing Record 12 of Set 8 | huarmey
# Processing Record 13 of Set 8 | sheridan
# Processing Record 14 of Set 8 | bajo baudo
# This city was not located >> bajo baudo Skipping...
# Processing Record 15 of Set 8 | severo-kurilsk
# Processing Record 16 of Set 8 | bressanone
# Processing Record 17 of Set 8 | honningsvag
# Processing Record 18 of Set 8 | navabad
# This city was not located >> navabad Skipping...
# Processing Record 19 of Set 8 | baikunthpur
# Processing Record 20 of Set 8 | morristown
# Processing Record 21 of Set 8 | sena madureira
# Processing Record 22 of Set 8 | pec
# Processing Record 23 of Set 8 | iqaluit
# Processing Record 24 of Set 8 | maine-soroa
# Processing Record 25 of Set 8 | praia
# Processing Record 26 of Set 8 | cayenne
# Processing Record 27 of Set 8 | torres
# Processing Record 28 of Set 8 | airai
# Processing Record 29 of Set 8 | udachnyy
# Processing Record 30 of Set 8 | pacific grove
# Processing Record 31 of Set 8 | coruripe
# Processing Record 32 of Set 8 | beira
# Processing Record 33 of Set 8 | pasinler
# Processing Record 34 of Set 8 | anda
# Processing Record 35 of Set 8 | matagami
# Processing Record 36 of Set 8 | chifeng
# Processing Record 37 of Set 8 | marzuq
# Processing Record 38 of Set 8 | namtsy
# Processing Record 39 of Set 8 | mogadishu
# Processing Record 40 of Set 8 | bilibino
# Processing Record 41 of Set 8 | moose factory
# Processing Record 42 of Set 8 | potiskum
# Processing Record 43 of Set 8 | la asuncion
# Processing Record 44 of Set 8 | port blair
# Processing Record 45 of Set 8 | lorengau
# Processing Record 46 of Set 8 | changping
# Processing Record 47 of Set 8 | sakaiminato
# Processing Record 48 of Set 8 | grindavik
# Processing Record 49 of Set 8 | cruz alta
# Processing Record 50 of Set 8 | mullaitivu
# This city was not located >> mullaitivu Skipping...
# Processing Record 1 of Set 9 | manado
# Processing Record 2 of Set 9 | chokwe
# Processing Record 3 of Set 9 | jining
# Processing Record 4 of Set 9 | salgueiro
# Processing Record 5 of Set 9 | anaconda
# Processing Record 6 of Set 9 | debre sina
# Processing Record 7 of Set 9 | san juan
# Processing Record 8 of Set 9 | asau
# Processing Record 9 of Set 9 | mahibadhoo
# Processing Record 10 of Set 9 | tahta
# Processing Record 11 of Set 9 | grootfontein
# Processing Record 12 of Set 9 | dubbo
# Processing Record 13 of Set 9 | businga
# Processing Record 14 of Set 9 | kavaratti
# Processing Record 15 of Set 9 | tarko-sale
# Processing Record 16 of Set 9 | chipinge
# Processing Record 17 of Set 9 | mahon
# Processing Record 18 of Set 9 | puerto madryn
# Processing Record 19 of Set 9 | chiochis
# Processing Record 20 of Set 9 | bandarbeyla
# Processing Record 21 of Set 9 | yaan
# Processing Record 22 of Set 9 | khilok
# Processing Record 23 of Set 9 | gilgit
# Processing Record 24 of Set 9 | grimshaw
# Processing Record 25 of Set 9 | tome-acu
# This city was not located >> tome-acu Skipping...
# Processing Record 26 of Set 9 | bogande
# Processing Record 27 of Set 9 | xinzhou
# Processing Record 28 of Set 9 | saldanha
# Processing Record 29 of Set 9 | orsha
# Processing Record 30 of Set 9 | san luis
# Processing Record 31 of Set 9 | nurota
# Processing Record 32 of Set 9 | mahmudabad
# Processing Record 33 of Set 9 | kasongo-lunda
# Processing Record 34 of Set 9 | karaul
# This city was not located >> karaul Skipping...
# Processing Record 35 of Set 9 | biak
# Processing Record 36 of Set 9 | sorkjosen
# Processing Record 37 of Set 9 | krasnoselkup
# Processing Record 38 of Set 9 | yokadouma
# Processing Record 39 of Set 9 | camana
# Processing Record 40 of Set 9 | wuzhou
# Processing Record 41 of Set 9 | kayerkan
# Processing Record 42 of Set 9 | canillo
# Processing Record 43 of Set 9 | ahipara
# Processing Record 44 of Set 9 | bad sankt leonhard
# This city was not located >> bad sankt leonhard Skipping...
# Processing Record 45 of Set 9 | okulovka
# Processing Record 46 of Set 9 | ilulissat
# Processing Record 47 of Set 9 | urdzhar
# This city was not located >> urdzhar Skipping...
# Processing Record 48 of Set 9 | bloemfontein
# Processing Record 49 of Set 9 | burgos
# Processing Record 50 of Set 9 | abu samrah
# Processing Record 1 of Set 10 | lebu
# Processing Record 2 of Set 10 | urubamba
# Processing Record 3 of Set 10 | merrill
# Processing Record 4 of Set 10 | jibuti
# Processing Record 5 of Set 10 | mount isa
# Processing Record 6 of Set 10 | abu dhabi
# Processing Record 7 of Set 10 | tongsa
# This city was not located >> tongsa Skipping...
# Processing Record 8 of Set 10 | falealupo
# This city was not located >> falealupo Skipping...
# Processing Record 9 of Set 10 | ruatoria
# This city was not located >> ruatoria Skipping...
# Processing Record 10 of Set 10 | stokmarknes
# Processing Record 11 of Set 10 | saskatoon
# Processing Record 12 of Set 10 | bonao
# Processing Record 13 of Set 10 | nouadhibou
# Processing Record 14 of Set 10 | longonjo
# Processing Record 15 of Set 10 | eldikan
# This city was not located >> eldikan Skipping...
# Processing Record 16 of Set 10 | tecoanapa
# Processing Record 17 of Set 10 | paragould
# Processing Record 18 of Set 10 | vila franca do campo
# Processing Record 19 of Set 10 | xiamen
# Processing Record 20 of Set 10 | jieznas
# Processing Record 21 of Set 10 | kushima
# Processing Record 22 of Set 10 | vila do maio
# Processing Record 23 of Set 10 | bombay
# Processing Record 24 of Set 10 | santa marta
# Processing Record 25 of Set 10 | padang
# Processing Record 26 of Set 10 | magadan
# Processing Record 27 of Set 10 | kez
# Processing Record 28 of Set 10 | owando
# Processing Record 29 of Set 10 | maldonado
# Processing Record 30 of Set 10 | brookhaven
# Processing Record 31 of Set 10 | payakumbuh
# Processing Record 32 of Set 10 | fortuna
# Processing Record 33 of Set 10 | covington
# Processing Record 34 of Set 10 | abeche
# Processing Record 35 of Set 10 | umtata
# Processing Record 36 of Set 10 | warmbad
# Processing Record 37 of Set 10 | ouadda
# Processing Record 38 of Set 10 | kirakira
# Processing Record 39 of Set 10 | chernyshevskiy
# Processing Record 40 of Set 10 | san giovanni in fiore
# Processing Record 41 of Set 10 | lakselv
# Processing Record 42 of Set 10 | banjar
# Processing Record 43 of Set 10 | san rafael
# Processing Record 44 of Set 10 | bedele
# Processing Record 45 of Set 10 | poya
# Processing Record 46 of Set 10 | porto murtinho
# Processing Record 47 of Set 10 | sola
# Processing Record 48 of Set 10 | ler
# Processing Record 49 of Set 10 | okha
# Processing Record 50 of Set 10 | nadvoitsy
# Processing Record 1 of Set 11 | rungata
# This city was not located >> rungata Skipping...
# Processing Record 2 of Set 11 | sistranda
# Processing Record 3 of Set 11 | casino
# Processing Record 4 of Set 11 | takoradi
# Processing Record 5 of Set 11 | angra dos reis
# Processing Record 6 of Set 11 | port-cartier
# Processing Record 7 of Set 11 | kautokeino
# Processing Record 8 of Set 11 | mishelevka
# Processing Record 9 of Set 11 | gushi
# Processing Record 10 of Set 11 | phangnga
# Processing Record 11 of Set 11 | araouane
# Processing Record 12 of Set 11 | tumannyy
# This city was not located >> tumannyy Skipping...
# Processing Record 13 of Set 11 | port hardy
# Processing Record 14 of Set 11 | praya
# Processing Record 15 of Set 11 | husavik
# Processing Record 16 of Set 11 | hamilton
# Processing Record 17 of Set 11 | dickinson
# Processing Record 18 of Set 11 | sabang
# Processing Record 19 of Set 11 | seinajoki
# Processing Record 20 of Set 11 | solano
# Processing Record 21 of Set 11 | necochea
# Processing Record 22 of Set 11 | laguna
# Processing Record 23 of Set 11 | kenai
# Processing Record 24 of Set 11 | fort saint john
# This city was not located >> fort saint john Skipping...
# Processing Record 25 of Set 11 | komsomolskiy
# Processing Record 26 of Set 11 | vysokogornyy
# Processing Record 27 of Set 11 | chulym
# Processing Record 28 of Set 11 | najran
# Processing Record 29 of Set 11 | zhongxing
# Processing Record 30 of Set 11 | sampit
# Processing Record 31 of Set 11 | awjilah
# Processing Record 32 of Set 11 | saint-joseph
# Processing Record 33 of Set 11 | rawson
# Processing Record 34 of Set 11 | roma
# Processing Record 35 of Set 11 | san cristobal
# Processing Record 36 of Set 11 | matara
# Processing Record 37 of Set 11 | kiri buru
# Processing Record 38 of Set 11 | zhanaozen
# Processing Record 39 of Set 11 | nivala
# Processing Record 40 of Set 11 | abu kamal
# Processing Record 41 of Set 11 | sabha
# Processing Record 42 of Set 11 | severnyy
# Processing Record 43 of Set 11 | puerto escondido
# Processing Record 44 of Set 11 | cidreira
# Processing Record 45 of Set 11 | xining
# Processing Record 46 of Set 11 | marsh harbour
# Processing Record 47 of Set 11 | oksfjord
# Processing Record 48 of Set 11 | mercedes
# Processing Record 49 of Set 11 | zenzeli
# Processing Record 50 of Set 11 | xam nua
# Processing Record 1 of Set 12 | myingyan
# Processing Record 2 of Set 12 | palmer
# Processing Record 3 of Set 12 | tadine
# Processing Record 4 of Set 12 | sohag
# Processing Record 5 of Set 12 | tieli
# Processing Record 6 of Set 12 | roald
# Processing Record 7 of Set 12 | pevek
# Processing Record 8 of Set 12 | olinda
# Processing Record 9 of Set 12 | sheopur
# Processing Record 10 of Set 12 | haines junction
# Processing Record 11 of Set 12 | verkhniy avzyan
# Processing Record 12 of Set 12 | valjevo
# Processing Record 13 of Set 12 | dibulla
# Processing Record 14 of Set 12 | itacoatiara
# Processing Record 15 of Set 12 | salinas
# Processing Record 16 of Set 12 | killarney
# Processing Record 17 of Set 12 | beloha
# Processing Record 18 of Set 12 | orcopampa
# Processing Record 19 of Set 12 | luz
# Processing Record 20 of Set 12 | batemans bay
# Processing Record 21 of Set 12 | khormuj
# This city was not located >> khormuj Skipping...
# Processing Record 22 of Set 12 | iki-burul
# Processing Record 23 of Set 12 | muisne
# Processing Record 24 of Set 12 | alyangula
# Processing Record 25 of Set 12 | oriximina
# Processing Record 26 of Set 12 | dryden
# Processing Record 27 of Set 12 | karaton
# Processing Record 28 of Set 12 | avera
# Processing Record 29 of Set 12 | sonipat
# Processing Record 30 of Set 12 | mossendjo
# Processing Record 31 of Set 12 | norden
# Processing Record 32 of Set 12 | kollumerland
# This city was not located >> kollumerland Skipping...
# Processing Record 33 of Set 12 | mwinilunga
# Processing Record 34 of Set 12 | polovinnoye
# Processing Record 35 of Set 12 | cam ranh
# Processing Record 36 of Set 12 | ecoporanga
# Processing Record 37 of Set 12 | aleksandrovskiy zavod
# Processing Record 38 of Set 12 | basco
# Processing Record 39 of Set 12 | manati
# Processing Record 40 of Set 12 | kirovskiy
# Processing Record 41 of Set 12 | vardo
# Processing Record 42 of Set 12 | hovd
# Processing Record 43 of Set 12 | kologriv
# Processing Record 44 of Set 12 | aberdeen
# Processing Record 45 of Set 12 | kargasok
# Processing Record 46 of Set 12 | kade
# Processing Record 47 of Set 12 | ambulu
# Processing Record 48 of Set 12 | iralaya
# Processing Record 49 of Set 12 | khuzhir
# Processing Record 50 of Set 12 | otradnoye
# Processing Record 1 of Set 13 | yenagoa
# Processing Record 2 of Set 13 | lyuban
# Processing Record 3 of Set 13 | jabinyanah
# Processing Record 4 of Set 13 | gewane
# Processing Record 5 of Set 13 | dzilam gonzalez
# Processing Record 6 of Set 13 | ravar
# Processing Record 7 of Set 13 | aflu
# This city was not located >> aflu Skipping...
# Processing Record 8 of Set 13 | trebinje
# Processing Record 9 of Set 13 | grand river south east
# This city was not located >> grand river south east Skipping...
# Processing Record 10 of Set 13 | west fargo
# Processing Record 11 of Set 13 | chadan
# Processing Record 12 of Set 13 | bantou
# Processing Record 13 of Set 13 | cortes
# Processing Record 14 of Set 13 | lasa
# Processing Record 15 of Set 13 | niort
# Processing Record 16 of Set 13 | morehead
# Processing Record 17 of Set 13 | yeppoon
# Processing Record 18 of Set 13 | south venice
# Processing Record 19 of Set 13 | gragnano
# Processing Record 20 of Set 13 | kaita
# Processing Record 21 of Set 13 | belyy yar
# Processing Record 22 of Set 13 | beringovskiy
# Processing Record 23 of Set 13 | chekhov
# Processing Record 24 of Set 13 | belaya gora
# Processing Record 25 of Set 13 | nageshwari
# Processing Record 26 of Set 13 | touros
# Processing Record 27 of Set 13 | boguchany
# Processing Record 28 of Set 13 | inuvik
# Processing Record 29 of Set 13 | knysna
# Processing Record 30 of Set 13 | aksum
# Processing Record 31 of Set 13 | sur
# Processing Record 32 of Set 13 | kedrovyy
# Processing Record 33 of Set 13 | golaghat
# Processing Record 34 of Set 13 | derzhavinsk
# Processing Record 35 of Set 13 | jalu
# Processing Record 36 of Set 13 | podor
# Processing Record 37 of Set 13 | funadhoo
# Processing Record 38 of Set 13 | jaramana
# This city was not located >> jaramana Skipping...
# Processing Record 39 of Set 13 | ixtapa
# Processing Record 40 of Set 13 | sanger
# Processing Record 41 of Set 13 | cockburn town
# Processing Record 42 of Set 13 | jimeta
# Processing Record 43 of Set 13 | ishinomaki
# Processing Record 44 of Set 13 | loucovice
# Processing Record 45 of Set 13 | liyang
# Processing Record 46 of Set 13 | swan hill
# Processing Record 47 of Set 13 | bellary
# Processing Record 48 of Set 13 | vallenar
# Processing Record 49 of Set 13 | sabla
# Processing Record 50 of Set 13 | muriae
# Processing Record 1 of Set 14 | kahului
# Processing Record 2 of Set 14 | tena
# Processing Record 3 of Set 14 | tidore
# This city was not located >> tidore Skipping...
# Processing Record 4 of Set 14 | takahagi
# Processing Record 5 of Set 14 | alcudia
# Processing Record 6 of Set 14 | port antonio
# Processing Record 7 of Set 14 | deputatskiy
# Processing Record 8 of Set 14 | krasnoye
# Processing Record 9 of Set 14 | amga
# Processing Record 10 of Set 14 | nova odesa
# Processing Record 11 of Set 14 | tefe
# Processing Record 12 of Set 14 | formoso do araguaia
# This city was not located >> formoso do araguaia Skipping...
# Processing Record 13 of Set 14 | bagotville
# Processing Record 14 of Set 14 | cururupu
# Processing Record 15 of Set 14 | qingquan
# Processing Record 16 of Set 14 | hambantota
# Processing Record 17 of Set 14 | santana
# Processing Record 18 of Set 14 | zheshart
# Processing Record 19 of Set 14 | shangqiu
# Processing Record 20 of Set 14 | port macquarie
# Processing Record 21 of Set 14 | progreso
# Processing Record 22 of Set 14 | eureka
# Processing Record 23 of Set 14 | hirara
# Processing Record 24 of Set 14 | talnakh
# Processing Record 25 of Set 14 | prince rupert
# Processing Record 26 of Set 14 | king city
# Processing Record 27 of Set 14 | shieli
# Processing Record 28 of Set 14 | baykit
# Processing Record 29 of Set 14 | broken hill
# Processing Record 30 of Set 14 | guanare
# Processing Record 31 of Set 14 | roquetas de mar
# Processing Record 32 of Set 14 | noboribetsu
# Processing Record 33 of Set 14 | tapaua
# This city was not located >> tapaua Skipping...
# Processing Record 34 of Set 14 | hofn
# Processing Record 35 of Set 14 | lokosovo
# Processing Record 36 of Set 14 | caxito
# Processing Record 37 of Set 14 | teya
# Processing Record 38 of Set 14 | khor
# Processing Record 39 of Set 14 | wuda
# Processing Record 40 of Set 14 | marrakesh
# Processing Record 41 of Set 14 | vertientes
# Processing Record 42 of Set 14 | klaipeda
# Processing Record 43 of Set 14 | namatanai
# Processing Record 44 of Set 14 | tazovskiy
# Processing Record 45 of Set 14 | outjo
# Processing Record 46 of Set 14 | pangkalanbuun
# Processing Record 47 of Set 14 | goderich
# Processing Record 48 of Set 14 | tevriz
# Processing Record 49 of Set 14 | pizarro
# Processing Record 50 of Set 14 | turukhansk
# Processing Record 1 of Set 15 | zhigansk
# Processing Record 2 of Set 15 | sinnai
# Processing Record 3 of Set 15 | peniche
# Processing Record 4 of Set 15 | belo oriente
# Processing Record 5 of Set 15 | pahrump
# Processing Record 6 of Set 15 | mrirt
# This city was not located >> mrirt Skipping...
# Processing Record 7 of Set 15 | qui nhon
# Processing Record 8 of Set 15 | wanning
# Processing Record 9 of Set 15 | akyab
# Processing Record 10 of Set 15 | kiunga
# Processing Record 11 of Set 15 | novouzensk
# Processing Record 12 of Set 15 | ceres
# Processing Record 13 of Set 15 | kudahuvadhoo
# Processing Record 14 of Set 15 | veracruz
# Processing Record 15 of Set 15 | kidal
# Processing Record 16 of Set 15 | macau
# Processing Record 17 of Set 15 | palana
# Processing Record 18 of Set 15 | voh
# Processing Record 19 of Set 15 | lubaczow
# Processing Record 20 of Set 15 | vao
# Processing Record 21 of Set 15 | solvychegodsk
# Processing Record 22 of Set 15 | borogontsy
# Processing Record 23 of Set 15 | chase
# Processing Record 24 of Set 15 | paragominas
# Processing Record 25 of Set 15 | campoverde
# Processing Record 26 of Set 15 | gorno-chuyskiy
# This city was not located >> gorno-chuyskiy Skipping...
# Processing Record 27 of Set 15 | rawannawi
# This city was not located >> rawannawi Skipping...
# Processing Record 28 of Set 15 | stornoway
# Processing Record 29 of Set 15 | lata
# Processing Record 30 of Set 15 | manta
# Processing Record 31 of Set 15 | humaita
# Processing Record 32 of Set 15 | sundargarh
# Processing Record 33 of Set 15 | olkhovka
# Processing Record 34 of Set 15 | pinotepa nacional
# Processing Record 35 of Set 15 | hearst
# Processing Record 36 of Set 15 | hurghada
# Processing Record 37 of Set 15 | dzaoudzi
# Processing Record 38 of Set 15 | buraydah
# Processing Record 39 of Set 15 | ust-kamchatsk
# This city was not located >> ust-kamchatsk Skipping...
# Processing Record 40 of Set 15 | nemuro
# Processing Record 41 of Set 15 | sattahip
# Processing Record 42 of Set 15 | talawdi
# This city was not located >> talawdi Skipping...
# Processing Record 43 of Set 15 | lormi
# Processing Record 44 of Set 15 | verkhnyaya khava
# Processing Record 45 of Set 15 | bababe
# This city was not located >> bababe Skipping...
# Processing Record 46 of Set 15 | beyneu
# Processing Record 47 of Set 15 | tonkino
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 689

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Jamestown  42.0970  -79.2353     37.02        97         100
# 1        Punta Arenas -53.1500  -70.9167     37.51        81          40
# 2        Norman Wells  65.2820 -126.8329     30.24        93         100
# 3              Atuona  -9.8000 -139.0333     76.89        74           4
# 4                Gizo  -8.1030  156.8419     84.97        67          80
# ..                ...      ...       ...       ...       ...         ...
# 684          Sattahip  12.6664  100.9007     86.99        57          75
# 685             Lormi  22.2833   81.7333     78.44        49           0
# 686  Verkhnyaya Khava  51.8404   39.9413     39.27        85         100
# 687            Beyneu  45.3167   55.2000     54.07        45         100
# 688           Tonkino  57.3726   46.4629     35.89        90          92
#
#      Wind Speed Country Current Description
# 0          9.22      US     overcast clouds
# 1         20.71      CL    scattered clouds
# 2         10.36      CA          light snow
# 3         12.91      PF           clear sky
# 4          6.33      SB       broken clouds
# ..          ...     ...                 ...
# 684        4.61      TH                haze
# 685        3.04      IN           clear sky
# 686        0.98      RU     overcast clouds
# 687       19.69      KZ     overcast clouds
# 688        4.79      RU     overcast clouds
#
# [689 rows x 9 columns]

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
updated_city_data_df = city_data_df[new_column_order]

# Display sample data
updated_city_data_df
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0           Jamestown      US  42.0970  -79.2353     37.02        97
# 1        Punta Arenas      CL -53.1500  -70.9167     37.51        81
# 2        Norman Wells      CA  65.2820 -126.8329     30.24        93
# 3              Atuona      PF  -9.8000 -139.0333     76.89        74
# 4                Gizo      SB  -8.1030  156.8419     84.97        67
# ..                ...     ...      ...       ...       ...       ...
# 684          Sattahip      TH  12.6664  100.9007     86.99        57
# 685             Lormi      IN  22.2833   81.7333     78.44        49
# 686  Verkhnyaya Khava      RU  51.8404   39.9413     39.27        85
# 687            Beyneu      KZ  45.3167   55.2000     54.07        45
# 688           Tonkino      RU  57.3726   46.4629     35.89        90
#
#      Cloudiness  Wind Speed Current Description
# 0           100        9.22     overcast clouds
# 1            40       20.71    scattered clouds
# 2           100       10.36          light snow
# 3             4       12.91           clear sky
# 4            80        6.33       broken clouds
# ..          ...         ...                 ...
# 684          75        4.61                haze
# 685           0        3.04           clear sky
# 686         100        0.98     overcast clouds
# 687         100       19.69     overcast clouds
# 688          92        4.79     overcast clouds
#
# [689 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
updated_city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
updated_city_data_df.to_csv(output_data_file, index_label="City_ID")
